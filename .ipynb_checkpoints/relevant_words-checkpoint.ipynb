# %%
import urllib3
import bs4
import pickle
import nltk
urllib3.disable_warnings()
from pycorenlp import StanfordCoreNLP


def make_soup(myurl):
    pm = urllib3.PoolManager()
    try:
        html = pm.urlopen(url = myurl, method = 'GET', redirect = False).data
        return bs4.BeautifulSoup(html, 'html5lib')
    except urllib3.exceptions.MaxRetryError:
        print('chingo a su madre')

def get_text_news(url, tag = 'p'):
    soup = make_soup(url)
    text = ' '.join([t.text for t in soup.find_all('p')])
    #print(url)
    return text

def get_entities(text, nlp):
    return nlp.annotate(text, properties={'annotators': 'ner', 'outputFormat': 'json'})

def get_alltext_entities(list_of_links):
    annotation_list = [get_entities(get_text_news(url), nlp) for url in list_of_links]
    return annotation_list

def get_entity_tup(annotator_dict):
    ners = []
    for sentence in annotator_dict['sentences']:
        for entity in sentence['entitymentions']:
            ners.append((entity['ner'],entity['text']))
    return ners

# %%
#Creating a StanfordCoreNLP object to comunicate with server in aws instance
nlp = StanfordCoreNLP('http://localhost:9000/')

# %%
links = ['https://www.elmostrador.cl/noticias/opinion/cartas/2018/11/25/contra-la-geopolitica-de-la-muerte-una-geografia-para-la-vida/',
 'http://www.elcomercio.com/tendencias/escena-premonitorio-serie-don-ramon.html',
 'https://tecnofanatico.com/neil-degrasse-tyson-ya-tendria-su-favorito-entre-steve-jobs-y-elon-musk/',
 'https://www.lanacion.com.ar/2189637-la-premonitoria-escena-grabo-don-ramon-antes',
 'https://tecnofanatico.com/samsung-tendra-que-indemnizar-a-sus-trabajadores-por-graves-enfermedades-laborales/',
 'http://vertele.eldiario.es/noticias/Tsunami-ficcion-espanola_0_2070692911.html',
 'https://exitoina.perfil.com/2018-11-09-564175-quico-revelo-la-impactante-premonicion-de-la-muerte-de-don-ramon/',
 'https://www.proceso.com.mx/559629/grupo-de-la-lux-ejercito-secreto-del-general-corona-del-rosal',
 'https://www.proceso.com.mx/561337/a-tres-dias-de-la-toma-de-protesta-de-amlo-liberan-a-maestro-opositor-a-la-reforma-educativa',
 'https://www.excelsior.com.mx/comunidad/bomberos-laboran-en-incendio-de-relleno-sanitario-en-edomex/1280670',
 'https://www.excelsior.com.mx/nacional/dominan-80-celulas-del-narco-en-mexico-operan-seis-carteles/1280724',
 'https://www.eluniversal.com.mx/metropoli/identifican-restos-de-ocho-victimas-de-pareja-feminicida',
 'https://www.proceso.com.mx/561296/matan-a-una-universitaria-en-presunto-asalto-en-puebla',
 'https://www.bbc.com/mundo/noticias-america-latina-46245076',
 'https://www.proceso.com.mx/558753/detienen-al-lider-de-los-aztecas-en-chihuahua',
 'https://www.excelsior.com.mx/nacional/velan-a-alumna-de-la-buap-y-a-su-hermano-padres-piden-justicia/1276935',
 'https://www.jornada.com.mx/2018/11/09/politica/008n1pol?partner=rss',
 'https://www.excelsior.com.mx/nacional/esto-cuesta-vivir-en-ciudades-clave-de-la-revolucion-mexicana/1279665',
 'https://news.culturacolectiva.com/ciencia/fallece-primera-persona-en-queretaro-por-influeza-estacional/',
 'https://www.excelsior.com.mx/nacional/secuestran-a-director-de-una-secundaria-en-sinaloa/1277130',
 'https://www.proceso.com.mx/560741/pueblos-de-la-cuenca-del-papaloapan-rechazan-megaproyectos-mineros-e-hidroelectricos',
 'https://www.animalpolitico.com/2018/11/desigualdad-esperanza-vida-estudio/',
 'https://www.excelsior.com.mx/comunidad/este-fue-el-destino-preferido-de-los-capitalinos-para-huir-del-megacorte/1277347',
 'https://www.animalpolitico.com/2018/11/guardia-nacional-constitucion-cndh/',
 'https://www.eluniversal.com.mx/nacion/tengan-paciencia-porque-el-pais-esta-en-quiebra-lopez-obrador',
 'https://www.jornada.com.mx/2018/11/16/politica/007n3pol?partner=rss',
 'https://www.excelsior.com.mx/global/dos-muertos-y-tres-desaparecidos-tras-hundimiento-de-carretera-en-portugal/1279565',
 'http://www.eluniversal.com.mx/cartera/122-millones-de-mujeres-en-mexico-han-sido-violentadas-de-forma-severa-inegi',
 'https://www.jornada.com.mx/2018/11/28/politica/015n1pol?partner=rss',
 'https://www.jornada.com.mx/2018/11/10/politica/012n1pol?partner=rss',
 'https://www.jornada.com.mx/2018/11/09/politica/014n1pol?partner=rss']

# %%
tagged_news = get_alltext_entities(links)

# %%
entities_word = []
for article in tagged_news:
    entities_word += get_entity_tup(article)

# %%
entities_word
# Out:
# [('LOCATION', 'Santiago'),
#  ('DATE', 'domingo'),
#  ('DATE', '9 de diciembre de 2018'),
#  ('ORGANIZATION', 'Viviana Huiliñir-Curío'),
#  ('PERSON', 'Pablo Mansilla'),
#  ('NUMBER', '25'),
#  ('DATE', 'noviembre'),
#  ('NUMBER', '2018'),
#  ('ORGANIZATION', 'Señor Director'),
#  ('PERSON', 'Lof'),
#  ('ORGANIZATION', 'peñi/lamngen'),
#  ('PERSON', 'Camilo Catrillanca'),
#  ('CAUSE_OF_DEATH', 'asesinado'),
#  ('ORGANIZATION', 'Carabineros'),
#  ('COUNTRY', 'Chile'),
#  ('DATE', 'miércoles'),
#  ('DATE', '14 de noviembre'),
#  ('LOCATION', 'Temucuicui Tradicional'),
#  ('LOCATION', 'Ercilla'),
#  ('CAUSE_OF_DEATH', 'violencia'),
#  ('ORGANIZATION', 'Estado'),
#  ('NATIONALITY', 'chileno'),
#  ('ORGANIZATION', 'Lof mapuche'),
#  ('ORGANIZATION', 'Wallmapu'),
#  ('DATE', 'hoy'),
#  ('LOCATION', 'Temucuicui'),
#  ('LOCATION', 'Wallmapu'),
#  ('ORGANIZATION', 'Grupo'),
#  ('MISC', 'Operaciones Policiales Especiales'),
#  ('ORGANIZATION', 'GOPE'),
#  ('ORGANIZATION', 'Comando Jungla'),
# ...

# %%
ent_words_dict = {}
for tup in entities_word:
    if tup[0] not in ent_words_dict.keys():
        ent_words_dict[tup[0]] = [tup[1]]
    else:
        ent_words_dict[tup[0]].append(tup[1])

# %%
ent_words_dict.keys()
# Out:
# dict_keys(['LOCATION', 'DATE', 'ORGANIZATION', 'PERSON', 'NUMBER', 'CAUSE_OF_DEATH', 'COUNTRY', 'NATIONALITY', 'MISC', 'TITLE', 'STATE_OR_PROVINCE', 'CITY', 'CRIMINAL_CHARGE', 'IDEOLOGY', 'RELIGION', 'MONEY', 'PERCENT'])

# %%
for element in list(ent_words_dict['ORGANIZATION']):
    if 'Cartel' in element:
        print(element)
# Out:
# Cartel

# %%
for key in ent_words_dict:
    print(key, len(set(ent_words_dict[key])))
# Out:
# LOCATION 274
# DATE 198
# ORGANIZATION 1004
# PERSON 1129
# NUMBER 411
# CAUSE_OF_DEATH 41
# COUNTRY 36
# NATIONALITY 13
# MISC 426
# TITLE 144
# STATE_OR_PROVINCE 9
# CITY 214
# CRIMINAL_CHARGE 30
# IDEOLOGY 11
# RELIGION 8
# MONEY 7
# PERCENT 78

# %%
set(ent_words_dict['CRIMINAL_CHARGE'])
# Out:
# {'Crímenes de odio',
#  'Drogas',
#  'Tren',
#  'abuso sexual',
#  'armas de fuego',
#  'asalto',
#  'asalto sexual',
#  'asesinato',
#  'chantaje',
#  'crimen organizado',
#  'crímenes de odio',
#  'delito',
#  'delitos',
#  'drogas',
#  'el tráfico de drogas',
#  'extorsión',
#  'fraude',
#  'homicidio',
#  'intimidación',
#  'lavado de dinero',
#  'posesión de armas',
#  'prostitución',
#  'robo a mano armada',
#  'secuestro',
#  'terrorismo',
#  'tortura',
#  'traición',
#  'tren',
#  'tráfico de drogas',
#  'violencia doméstica'}

# %%
set(ent_words_dict['CRIMINAL_CHARGE'])
# Out:
# {'CAUSE_OF_DEATH': ['asesinado',
#   'violencia',
#   'violencia',
#   'violencia',
#   'violencia',
#   'violencia',
#   'cáncer de estómago',
#   'cáncer de estómago',
#   'metástasis',
#   'cáncer de estómago',
#   'enfermedades',
#   'cáncer',
#   'enfermedades',
#   'cáncer',
#   'enfermedades',
#   'enfermedades',
#   'leucemia',
#   'Cirugía',
#   'accidente',
#   'cáncer de estómago',
#   'choque',
#   'fuego',
#   'choque',
#   'violencia',
#   'desastre',
#   'violencia',
#   'violencia',
#   'disparo',
#   'disparo',
#   'ejecuciones',
#   'ejecuciones',
#   'violencia',
#   'desastre',
#   'guerra',
#   'guerra',
#   'guerra',
#   'violencia',
#   'ataques',
#   'violencia',
#   'violencia',
#   'fuego',
#   'desastre',
#   'violencia',
#   'violencia',
#   'fuego',
#   'ataques',
#   'violencia',
#   'ataques',
#   'violencia',
#   'violencia',
#   'fuego',
#   'Violencia',
#   'Violencia',
#   'violencia',
#   'Violencia',
#   'Violencia',
#   'violencia',
# ...

# %%
make_soup('https://www.elheraldo.hn/minisitios/hondurenosenelmundo/1236471-471/colarse-a-estados-unidos-o-quedarse-en-m%C3%A9xico-la-disyuntiva-de-la')
# Out:
# <!DOCTYPE html>
# <!-- fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/Utilitarios/getAmp.csp --><!--/fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/Utilitarios/getAmp.csp, e:.000206 --><html lang="es-HN"><!-- fi:/csp/mediapool/sites/ElHeraldo/assets/cspv2/StoryDefault.csp --><!-- fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/helper/versiones.csp --><!--/fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/helper/versiones.csp, e:.000104 --><!-- fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/helper/detectMobileDevice.csp --><!--/fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/helper/detectMobileDevice.csp, e:.000089 --><!-- fi:/csp/mediapool/sites/ElHeraldo/assets/csp/helper/getCustomFields.csp --><!--/fi:/csp/mediapool/sites/ElHeraldo/assets/csp/helper/getCustomFields.csp, e:.000152 --><head>
#
# <!-- fi:/csp/mediapool/sites/ElHeraldo/assets/cspV2/headfiles/head.csp -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
' '.join([t.text for t in b.find_all('p')])
# Out:
# '\nPor: \nCultura Colectiva\n\n \nPor: \nCultura Colectiva\n\n Texto por Daniel Lobos Jeria Nació como José Gabriel Condorcanqui Noguera pero este cacique indígena que encabezó una de las primeras insurgencias indígenas, una de las más numerosas y sangrientas de la historia latinoamericana, se convirtió en Tupac Amaru II, “la serpiente resplandeciente” en lengua quechua. Hijo del siglo XVIII, su nacimiento se rastrea en Surinama, en lo que en esos tiempos era conocido como el Virreinato del Perú, aunque José Condorcanqui era mestizo, por su sangre corría la historia funesta de la conquista española pues era descendiente directo del ultimo Sapa Inca que había sido ejecutado trágicamente por los castellanos. Condorcanqui en vano lucho en su vida para que se le reconociera su linaje real. En sus primeros años fue criado hasta su adolescencia por el sacerdote criollo Antonio López de Sosa, quien le brindó una educación jesuita, misma que lo llevo más tarde a interesarse por el latín, las
# ...

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer("spanish")

# %%
stemmer.stem('serial')
# Out:
# 'serial'

# %%
tokens = [t.text for t in b.find_all('p')]

# %%
tokens[0]
# Out:
# 'Algunos integrantes de la caravana se han inscrito en listas de espera para tramitar en México el asilo en Estados Unidos'

# %%
[stemmer.stem(word) for word in nltk.word_tokenize(tokens[0])]
# Out:
# ['algun',
#  'integr',
#  'de',
#  'la',
#  'caravan',
#  'se',
#  'han',
#  'inscrit',
#  'en',
#  'list',
#  'de',
#  'esper',
#  'par',
#  'tramit',
#  'en',
#  'mexic',
#  'el',
#  'asil',
#  'en',
#  'estad',
#  'unid']

# %%
'CRIMINAL_CHARGE' in ['CAUSE_OF_DEATH', 'CRIMINAL_CHARGE']
# Out:
# True
